# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../report/result.csv")

df.head()
# Out:
#     tag        F1  size
# 0    19  0.997043   536
# 1   398  0.995384   550
# 2  1108  0.997039   599
# 3   213  0.997029   536
# 4   821  0.998416   578

# %%
plt.hist(df["size"], bins=30)
plt.show()

# %%
plt.hist(df["F1"], bins=30)
plt.show()

# %%
plt.scatter(df["size"], df["F1"], )
plt.show()
